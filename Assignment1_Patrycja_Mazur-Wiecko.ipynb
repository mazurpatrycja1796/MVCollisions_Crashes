# %%
import pandas as pd
import numpy as np

# %%
MVCollisions = pd.read_csv('Motor_Vehicle_Collisions_-_Crashes_20251118.csv')
MVCollisions.head()
# Out:
# /var/folders/_y/s628k2vs55v2kxzpds3m7cpc0000gn/T/ipykernel_69442/3866698553.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   MVCollisions = pd.read_csv('Motor_Vehicle_Collisions_-_Crashes_20251118.csv')
#    CRASH DATE CRASH TIME   BOROUGH ZIP CODE  LATITUDE  LONGITUDE  \
# 0  09/11/2021       2:39       NaN      NaN       NaN        NaN
# 1  03/26/2022      11:45       NaN      NaN       NaN        NaN
# 2  11/01/2023       1:29  BROOKLYN  11230.0  40.62179 -73.970024
# 3  06/29/2022       6:55       NaN      NaN       NaN        NaN
# 4  09/21/2022      13:21       NaN      NaN       NaN        NaN
#
#                      LOCATION           ON STREET NAME CROSS STREET NAME  \
# 0                         NaN    WHITESTONE EXPRESSWAY         20 AVENUE
# 1                         NaN  QUEENSBORO BRIDGE UPPER               NaN
# 2      (40.62179, -73.970024)            OCEAN PARKWAY          AVENUE K
# 3                         NaN       THROGS NECK BRIDGE               NaN
# 4                         NaN          BROOKLYN BRIDGE               NaN
#
#   OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 2  \
# 0             NaN  ...                    Unspecified
# 1             NaN  ...                            NaN
# 2             NaN  ...                    Unspecified
# 3             NaN  ...                    Unspecified
# 4             NaN  ...                    Unspecified
#
#    CONTRIBUTING FACTOR VEHICLE 3  CONTRIBUTING FACTOR VEHICLE 4  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                    Unspecified                            NaN
# 3                            NaN                            NaN
# 4                            NaN                            NaN
#
#    CONTRIBUTING FACTOR VEHICLE 5  COLLISION_ID  \
# 0                            NaN       4455765
# 1                            NaN       4513547
# 2                            NaN       4675373
# 3                            NaN       4541903
# 4                            NaN       4566131
#
#                    VEHICLE TYPE CODE 1  VEHICLE TYPE CODE 2  \
# 0                                Sedan                Sedan
# 1                                Sedan                  NaN
# 2                                Moped                Sedan
# 3                                Sedan        Pick-up Truck
# 4  Station Wagon/Sport Utility Vehicle                  NaN
#
#    VEHICLE TYPE CODE 3 VEHICLE TYPE CODE 4 VEHICLE TYPE CODE 5
# 0                  NaN                 NaN                 NaN
# 1                  NaN                 NaN                 NaN
# 2                Sedan                 NaN                 NaN
# 3                  NaN                 NaN                 NaN
# 4                  NaN                 NaN                 NaN
#
# [5 rows x 29 columns]

# %%
MVCollisions.columns
# Out:
# Index(['CRASH DATE', 'CRASH TIME', 'BOROUGH', 'ZIP CODE', 'LATITUDE',
#        'LONGITUDE', 'LOCATION', 'ON STREET NAME', 'CROSS STREET NAME',
#        'OFF STREET NAME', 'NUMBER OF PERSONS INJURED',
#        'NUMBER OF PERSONS KILLED', 'NUMBER OF PEDESTRIANS INJURED',
#        'NUMBER OF PEDESTRIANS KILLED', 'NUMBER OF CYCLIST INJURED',
#        'NUMBER OF CYCLIST KILLED', 'NUMBER OF MOTORIST INJURED',
#        'NUMBER OF MOTORIST KILLED', 'CONTRIBUTING FACTOR VEHICLE 1',
#        'CONTRIBUTING FACTOR VEHICLE 2', 'CONTRIBUTING FACTOR VEHICLE 3',
#        'CONTRIBUTING FACTOR VEHICLE 4', 'CONTRIBUTING FACTOR VEHICLE 5',
#        'COLLISION_ID', 'VEHICLE TYPE CODE 1', 'VEHICLE TYPE CODE 2',
#        'VEHICLE TYPE CODE 3', 'VEHICLE TYPE CODE 4', 'VEHICLE TYPE CODE 5'],
#       dtype='object')

# %%
# !pip install google-cloud-storage
# Out:
# Requirement already satisfied: google-cloud-storage in /opt/anaconda3/lib/python3.12/site-packages (3.6.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.26.1 in /opt/anaconda3/lib/python3.12/site-packages (from google-cloud-storage) (2.43.0)
# Requirement already satisfied: google-api-core<3.0.0,>=2.27.0 in /opt/anaconda3/lib/python3.12/site-packages (from google-cloud-storage) (2.28.1)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.2 in /opt/anaconda3/lib/python3.12/site-packages (from google-cloud-storage) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.7.2 in /opt/anaconda3/lib/python3.12/site-packages (from google-cloud-storage) (2.8.0)
# Requirement already satisfied: requests<3.0.0,>=2.22.0 in /opt/anaconda3/lib/python3.12/site-packages (from google-cloud-storage) (2.32.2)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in /opt/anaconda3/lib/python3.12/site-packages (from google-cloud-storage) (1.7.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /opt/anaconda3/lib/python3.12/site-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage) (1.72.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /opt/anaconda3/lib/python3.12/site-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage) (5.29.3)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /opt/anaconda3/lib/python3.12/site-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage) (1.26.1)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.26.1->google-cloud-storage) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/anaconda3/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.26.1->google-cloud-storage) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/anaconda3/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.26.1->google-cloud-storage) (4.9.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.22.0->google-cloud-storage) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.22.0->google-cloud-storage) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.22.0->google-cloud-storage) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.22.0->google-cloud-storage) (2025.10.5)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/anaconda3/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.26.1->google-cloud-storage) (0.4.8)

# %%
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/Users/patkaa/Documents/Assignment 1 - DW - Fall 2025/mvcollisionscrashes-aa77ca045e2e.json"

# %%
from google.cloud import storage
from datetime import datetime

# %%
local_file_path = "/Users/patkaa/Documents/Assignment 1 - DW - Fall 2025/Motor_Vehicle_Collisions_-_Crashes_20251118.csv"
bucket_name = "mvcollisions_bucket1"
